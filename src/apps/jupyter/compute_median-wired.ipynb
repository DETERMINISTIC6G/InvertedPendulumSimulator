# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_sets_lqr = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/wired/lqr-all-dn/"

data_sets_pid = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/wired/pid-all-dn/"

data_sets_pid_angle = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/wired/pid-angle-dn/"

data_sets_lqr_angle = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/wired/lqr-angle-dn/"

# %%
def stable_time(df_delay, threshold=0.00872665, window_duration=5.0):
    t = df_delay['t'].values
    angle = np.abs(df_delay['phi'].values)
    is_stable = angle < threshold
    n = len(t)
    start_idx = 0
    end_idx = 0

    while start_idx < n:
        while end_idx < n and t[end_idx] - t[start_idx] < window_duration:
            end_idx += 1
        
        if end_idx == n:
            break

        if is_stable[start_idx:end_idx].all():
            return t[start_idx]

        start_idx += 1

    return float("inf")

# %%
def median(data_sets, t):
    phi_medians = []
    phi_mse = []
    for filename in os.listdir(data_sets):
        if filename.endswith(".csv"):
            filepath = os.path.join(data_sets, filename)
            df = pd.read_csv(filepath, names= ['t', 'position', 'vx', 'phi', 'omega'], header=None, skiprows=1)
            df = df[df["t"] <= t]
            if "phi" in df.columns:
                
                df["phi_deg"] = np.degrees(df["phi"])
                print(filename)
                print("Maximaler phi_deg-Wert:", df["phi_deg"].max())
                print(f"Stabilization time: {stable_time(df):.6f}")
                median_phi = df["phi_deg"].median()
                phi_mse.append((df["phi_deg"]**2).mean())
                phi_medians.append(median_phi)
    phi_medians_sorted = np.sort(phi_medians)

    # 99% Confidence interval
    confidence_level = 0.99
    n = len(phi_medians_sorted )
    
    z = 1.288  # z-value for  99 % CI
    lower_idx = max(0, int(np.floor(0.5 * n - z * np.sqrt(n))))
    upper_idx = min(n - 1, int(np.ceil(0.5 * n + z * np.sqrt(n))))
    
    ci_lower = phi_medians_sorted[lower_idx]
    ci_upper = phi_medians_sorted[upper_idx]
    median = np.median(phi_medians_sorted )
    df = pd.DataFrame(phi_medians_sorted, columns=["medians"])
    summary = df["medians"].describe(percentiles=[0.01, 0.25, 0.5, 0.75, 0.99])
    print(summary)
    print(f"99% Confidence Interval for Median phy: [{ci_lower:.6f}, {ci_upper:.6f}]")
    
    return phi_medians_sorted, phi_mse

# %%
t = 60

# %%
phi_medians_lqr, phi_mse_lqr = median(data_sets_lqr, t)
# Out:
# lqr-all-dn-12.csv
# Maximaler phi_deg-Wert: 20.27342403135002
# Stabilization time: 5.424500
# lqr-all-dn-6.csv
# Maximaler phi_deg-Wert: 20.277320144356914
# Stabilization time: 5.424500
# lqr-all-dn-29.csv
# Maximaler phi_deg-Wert: 20.27371051024759
# Stabilization time: 5.424500
# lqr-all-dn-13.csv
# Maximaler phi_deg-Wert: 20.27600234142811
# Stabilization time: 5.424500
# lqr-all-dn-18.csv
# Maximaler phi_deg-Wert: 20.27371051024759
# Stabilization time: 5.424500
# lqr-all-dn-16.csv
# Maximaler phi_deg-Wert: 20.273767806027102
# Stabilization time: 5.424500
# lqr-all-dn-7.csv
# Maximaler phi_deg-Wert: 20.276861778120807
# Stabilization time: 5.424500
# lqr-all-dn-8.csv
# Maximaler phi_deg-Wert: 20.273595918688564
# Stabilization time: 5.424500
# lqr-all-dn-23.csv
# Maximaler phi_deg-Wert: 20.27393969336564
# Stabilization time: 5.424500
# lqr-all-dn-19.csv
# Maximaler phi_deg-Wert: 20.272736481995864
# Stabilization time: 5.424600
# lqr-all-dn-27.csv
# Maximaler phi_deg-Wert: 20.27485642583785
# Stabilization time: 5.424500
# lqr-all-dn-0.csv
# Maximaler phi_deg-Wert: 20.273538622909047
# Stabilization time: 5.424500
# lqr-all-dn-10.csv
# Maximaler phi_deg-Wert: 20.273653214468073
# Stabilization time: 5.424500
# lqr-all-dn-28.csv
# Maximaler phi_deg-Wert: 20.274971017396876
# Stabilization time: 5.424500
# lqr-all-dn-11.csv
# Maximaler phi_deg-Wert: 20.2750856089559
# Stabilization time: 5.424500
# lqr-all-dn-3.csv
# Maximaler phi_deg-Wert: 20.273767806027102
# Stabilization time: 5.424500
# lqr-all-dn-26.csv
# Maximaler phi_deg-Wert: 20.27468453849931
# Stabilization time: 5.424500
# lqr-all-dn-9.csv
# Maximaler phi_deg-Wert: 20.27393969336564
# Stabilization time: 5.424500
# lqr-all-dn-24.csv
# Maximaler phi_deg-Wert: 20.27371051024759
# Stabilization time: 5.424500
# lqr-all-dn-20.csv
# Maximaler phi_deg-Wert: 20.27371051024759
# Stabilization time: 5.424500
# lqr-all-dn-4.csv
# Maximaler phi_deg-Wert: 20.273595918688564
# Stabilization time: 5.424500
# lqr-all-dn-17.csv
# Maximaler phi_deg-Wert: 20.273538622909047
# Stabilization time: 5.424500
# lqr-all-dn-21.csv
# Maximaler phi_deg-Wert: 20.274913721617363
# Stabilization time: 5.424500
# lqr-all-dn-5.csv
# Maximaler phi_deg-Wert: 20.273767806027102
# Stabilization time: 5.424500
# lqr-all-dn-1.csv
# Maximaler phi_deg-Wert: 20.274913721617363
# Stabilization time: 5.424500
# lqr-all-dn-22.csv
# Maximaler phi_deg-Wert: 20.273882397586128
# Stabilization time: 5.424500
# lqr-all-dn-14.csv
# Maximaler phi_deg-Wert: 20.274913721617363
# Stabilization time: 5.424500
# lqr-all-dn-25.csv
# Maximaler phi_deg-Wert: 20.273882397586128
# Stabilization time: 5.424500
# lqr-all-dn-15.csv
# Maximaler phi_deg-Wert: 20.273538622909047
# Stabilization time: 5.424500
# lqr-all-dn-2.csv
# Maximaler phi_deg-Wert: 20.274799130058337
# Stabilization time: 5.424500
# count    3.000000e+01
# mean    -1.000849e-19
# std      7.519065e-24
# min     -1.000969e-19
# 1%      -1.000968e-19
# 25%     -1.000868e-19
# 50%     -1.000856e-19
# 75%     -1.000784e-19
# 99%     -1.000692e-19
# max     -1.000665e-19
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000000, -0.000000]

# %%
phi_medians_pid, phi_mse_pid = median(data_sets_pid, t)
# Out:
# pid-all-dn-28.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 8.191400
# pid-all-dn-27.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 8.242400
# pid-all-dn-3.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.286500
# pid-all-dn-7.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 7.959900
# pid-all-dn-13.csv
# Maximaler phi_deg-Wert: 19.999263726379922
# Stabilization time: 8.034900
# pid-all-dn-4.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.138000
# pid-all-dn-15.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.146700
# pid-all-dn-24.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.273100
# pid-all-dn-2.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 8.201400
# pid-all-dn-25.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.226500
# pid-all-dn-9.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.285400
# pid-all-dn-18.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.276300
# pid-all-dn-22.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.282300
# pid-all-dn-1.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 8.187000
# pid-all-dn-20.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.285300
# pid-all-dn-10.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.281300
# pid-all-dn-6.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 7.963200
# pid-all-dn-0.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.238900
# pid-all-dn-5.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.286200
# pid-all-dn-14.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 8.196400
# pid-all-dn-8.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.240600
# pid-all-dn-11.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 8.085400
# pid-all-dn-19.csv
# Maximaler phi_deg-Wert: 19.998690768584794
# Stabilization time: 8.280100
# pid-all-dn-29.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.236300
# pid-all-dn-17.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.238400
# pid-all-dn-12.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.242800
# pid-all-dn-23.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.234600
# pid-all-dn-16.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 8.271800
# pid-all-dn-21.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 8.093500
# pid-all-dn-26.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 8.147400
# count    3.000000e+01
# mean    -1.441078e-12
# std      7.516496e-14
# min     -1.695153e-12
# 1%      -1.687661e-12
# 25%     -1.448606e-12
# 50%     -1.432783e-12
# 75%     -1.392121e-12
# 99%     -1.379247e-12
# max     -1.379147e-12
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000000, -0.000000]

# %%
phi_medians_pid_angle, phi_mse_pid_angle = median(data_sets_pid_angle, t)
# Out:
# pid-angle-dn-17.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.041500
# pid-angle-dn-20.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.155100
# pid-angle-dn-29.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.040600
# pid-angle-dn-21.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 1.457900
# pid-angle-dn-5.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.155400
# pid-angle-dn-0.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.041500
# pid-angle-dn-1.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 1.873300
# pid-angle-dn-19.csv
# Maximaler phi_deg-Wert: 19.998690768584794
# Stabilization time: 2.155700
# pid-angle-dn-27.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 2.040700
# pid-angle-dn-11.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 1.457800
# pid-angle-dn-14.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 1.873100
# pid-angle-dn-9.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.155100
# pid-angle-dn-16.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.154400
# pid-angle-dn-8.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.041200
# pid-angle-dn-15.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 1.370100
# pid-angle-dn-3.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.155000
# pid-angle-dn-23.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.041500
# pid-angle-dn-26.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 1.370700
# pid-angle-dn-18.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.155000
# pid-angle-dn-6.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 1.715200
# pid-angle-dn-28.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 1.872800
# pid-angle-dn-4.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 1.369900
# pid-angle-dn-25.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.042500
# pid-angle-dn-7.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 1.715000
# pid-angle-dn-24.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.155400
# pid-angle-dn-2.csv
# Maximaler phi_deg-Wert: 19.999091839041387
# Stabilization time: 1.872700
# pid-angle-dn-22.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.154900
# pid-angle-dn-12.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.041700
# pid-angle-dn-10.csv
# Maximaler phi_deg-Wert: 19.998919951702845
# Stabilization time: 2.155300
# pid-angle-dn-13.csv
# Maximaler phi_deg-Wert: 19.999263726379922
# Stabilization time: 1.569200
# count    3.000000e+01
# mean     9.738760e-07
# std      1.013386e-05
# min     -2.458800e-05
# 1%      -2.458584e-05
# 25%     -3.810079e-06
# 50%      4.687614e-06
# 75%      9.751384e-06
# 99%      9.784411e-06
# max      9.789213e-06
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000005, 0.000010]

# %%
phi_medians_lqr_angle, phi_mse_lqr_angle = median(data_sets_lqr_angle, t)
# Out:
# lqr-angle-dn-7.csv
# Maximaler phi_deg-Wert: 20.00006586729311
# Stabilization time: 2.551100
# lqr-angle-dn-6.csv
# Maximaler phi_deg-Wert: 20.00006586729311
# Stabilization time: 2.551000
# lqr-angle-dn-25.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548200
# lqr-angle-dn-21.csv
# Maximaler phi_deg-Wert: 19.999664796836516
# Stabilization time: 2.549100
# lqr-angle-dn-15.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-28.csv
# Maximaler phi_deg-Wert: 19.999664796836516
# Stabilization time: 2.549200
# lqr-angle-dn-27.csv
# Maximaler phi_deg-Wert: 19.999664796836516
# Stabilization time: 2.549300
# lqr-angle-dn-17.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548200
# lqr-angle-dn-29.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548200
# lqr-angle-dn-2.csv
# Maximaler phi_deg-Wert: 19.999664796836516
# Stabilization time: 2.549200
# lqr-angle-dn-26.csv
# Maximaler phi_deg-Wert: 19.999664796836516
# Stabilization time: 2.549200
# lqr-angle-dn-16.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-10.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-23.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548200
# lqr-angle-dn-13.csv
# Maximaler phi_deg-Wert: 19.999836684175055
# Stabilization time: 2.550200
# lqr-angle-dn-0.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548400
# lqr-angle-dn-20.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-5.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-24.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-4.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-8.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548200
# lqr-angle-dn-3.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-22.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548100
# lqr-angle-dn-19.csv
# Maximaler phi_deg-Wert: 19.99920643060041
# Stabilization time: 2.547300
# lqr-angle-dn-9.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548200
# lqr-angle-dn-18.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548300
# lqr-angle-dn-14.csv
# Maximaler phi_deg-Wert: 19.999664796836516
# Stabilization time: 2.549200
# lqr-angle-dn-11.csv
# Maximaler phi_deg-Wert: 19.999664796836516
# Stabilization time: 2.549000
# lqr-angle-dn-1.csv
# Maximaler phi_deg-Wert: 19.999664796836516
# Stabilization time: 2.549200
# lqr-angle-dn-12.csv
# Maximaler phi_deg-Wert: 19.99943561371846
# Stabilization time: 2.548400
# count    3.000000e+01
# mean     2.814468e-10
# std      1.990861e-13
# min      2.811031e-10
# 1%       2.811634e-10
# 25%      2.813292e-10
# 50%      2.813504e-10
# 75%      2.815501e-10
# 99%      2.820005e-10
# max      2.820115e-10
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [0.000000, 0.000000]

# %%
data = [phi_medians_lqr, phi_medians_pid, phi_medians_pid_angle, phi_medians_lqr_angle]

plt.boxplot(data, positions=[1, 2, 3,4,], widths=0.6)
plt.xticks([1, 2,3 ,4], ['lqr', 'pid', 'pid_angle', 'lqr_angle'])
plt.title("Wired data set")
plt.ylabel("phi-Median")
plt.grid(True)


plt.savefig('wired_plotbox.png', dpi=300)
plt.show()

# %%
mse_dict = {
    'lqr': phi_mse_lqr,
    'pid': phi_mse_pid,
    'pid_angle': phi_mse_pid_angle,
    'lqr_angle': phi_mse_lqr_angle,
}

# Plot Setup
fig, axs = plt.subplots(1, 4, figsize=(16, 4), sharey=True)

for i, (label, data) in enumerate(mse_dict.items()):
    axs[i].hist(data, bins=10, color='skyblue', edgecolor='black')
    axs[i].set_title(label)
    axs[i].set_xlabel('MSE, squared degrees')
    axs[i].grid(True)

axs[0].set_ylabel('Count')
plt.suptitle('Histograms of MSE values for wired switch data set (4 methods)', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])

plt.savefig('wired_mse_hist.png', dpi=300)
plt.show()
