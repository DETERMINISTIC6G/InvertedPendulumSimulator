# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_sets_5g_1_lqr = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/truncnormal_10_2/lqr-all-dn/"
#phi_medians_5g_1_lqr = []

data_sets_5g_1_pid = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/truncnormal_10_2/pid-all-dn/"
#phi_medians_5g_1_pid = []

data_sets_5g_1_pid_angle = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/truncnormal_10_2/pid-angle-dn/"

data_sets_5g_1_lqr_angle = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/truncnormal_10_2/lqr-angle-dn/"

# %%
def median(data_sets, t):
    phi_medians = []
    for filename in os.listdir(data_sets):
        if filename.endswith(".csv"):
            filepath = os.path.join(data_sets, filename)
            df = pd.read_csv(filepath)
            df = df[df["t"] <= t]
            if "phi" in df.columns:
                
                df["phi_deg"] = np.degrees(df["phi"])
                print(filename)
                print("Maximaler phi_deg-Wert:", df["phi_deg"].max())
                median_phi = df["phi_deg"].median()
                phi_medians.append(median_phi)
    phi_medians_sorted = np.sort(phi_medians)

    # 99% Confidence interval
    confidence_level = 0.99
    n = len(phi_medians_sorted )
    
    z = 1.288  # z-value for  99 % CI
    lower_idx = max(0, int(np.floor(0.5 * n - z * np.sqrt(n))))
    upper_idx = min(n - 1, int(np.ceil(0.5 * n + z * np.sqrt(n))))
    
    ci_lower = phi_medians_sorted[lower_idx]
    ci_upper = phi_medians_sorted[upper_idx]
    median = np.median(phi_medians_sorted )
    df = pd.DataFrame(phi_medians_sorted, columns=["medians"])
    summary = df["medians"].describe(percentiles=[0.01, 0.25, 0.5, 0.75, 0.99])
    print(summary)
    print(f"99% Confidence Interval for Median phy: [{ci_lower:.6f}, {ci_upper:.6f}]")
    
    return phi_medians_sorted

# %%
t = 10

# %%
phi_medians_5g_1_lqr = median(data_sets_5g_1_lqr, t)
# Out:
# lqr-all-dn-12.csv
# Maximaler phi_deg-Wert: 20.854689714510243
# lqr-all-dn-6.csv
# Maximaler phi_deg-Wert: 20.836412360845568
# lqr-all-dn-29.csv
# Maximaler phi_deg-Wert: 20.865690504176758
# lqr-all-dn-13.csv
# Maximaler phi_deg-Wert: 20.853085432683876
# lqr-all-dn-18.csv
# Maximaler phi_deg-Wert: 20.89015580202884
# lqr-all-dn-16.csv
# Maximaler phi_deg-Wert: 20.844491065756912
# lqr-all-dn-7.csv
# Maximaler phi_deg-Wert: 20.873482730190535
# lqr-all-dn-8.csv
# Maximaler phi_deg-Wert: 20.878009096772068
# lqr-all-dn-23.csv
# Maximaler phi_deg-Wert: 20.87680588540229
# lqr-all-dn-19.csv
# Maximaler phi_deg-Wert: 20.86540402527919
# lqr-all-dn-27.csv
# Maximaler phi_deg-Wert: 20.78902875118825
# lqr-all-dn-0.csv
# Maximaler phi_deg-Wert: 20.90384949333247
# lqr-all-dn-10.csv
# Maximaler phi_deg-Wert: 20.858471235958106
# lqr-all-dn-28.csv
# Maximaler phi_deg-Wert: 20.888780703320528
# lqr-all-dn-11.csv
# Maximaler phi_deg-Wert: 20.832229768941115
# lqr-all-dn-3.csv
# Maximaler phi_deg-Wert: 20.84214193879688
# lqr-all-dn-26.csv
# Maximaler phi_deg-Wert: 20.82019765524337
# lqr-all-dn-9.csv
# Maximaler phi_deg-Wert: 20.847298558953057
# lqr-all-dn-24.csv
# Maximaler phi_deg-Wert: 20.83068278289426
# lqr-all-dn-20.csv
# Maximaler phi_deg-Wert: 20.89204656275277
# lqr-all-dn-4.csv
# Maximaler phi_deg-Wert: 20.826786669887372
# lqr-all-dn-17.csv
# Maximaler phi_deg-Wert: 20.91295952227505
# lqr-all-dn-21.csv
# Maximaler phi_deg-Wert: 20.869529321404134
# lqr-all-dn-5.csv
# Maximaler phi_deg-Wert: 20.820541429920446
# lqr-all-dn-1.csv
# Maximaler phi_deg-Wert: 20.875889152930082
# lqr-all-dn-22.csv
# Maximaler phi_deg-Wert: 20.763131058848337
# lqr-all-dn-14.csv
# Maximaler phi_deg-Wert: 20.87565996981203
# lqr-all-dn-25.csv
# Maximaler phi_deg-Wert: 20.85514808074635
# lqr-all-dn-15.csv
# Maximaler phi_deg-Wert: 20.86133602493376
# lqr-all-dn-2.csv
# Maximaler phi_deg-Wert: 20.88138954776334
# count    30.000000
# mean     -0.218203
# std       0.000033
# min      -0.218271
# 1%       -0.218269
# 25%      -0.218217
# 50%      -0.218198
# 75%      -0.218180
# 99%      -0.218151
# max      -0.218151
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.218217, -0.218172]

# %%
phi_medians_5g_1_pid = median(data_sets_5g_1_pid, t)
# Out:
# pid-all-dn-28.csv
# Maximaler phi_deg-Wert: 20.739296014570893
# pid-all-dn-27.csv
# Maximaler phi_deg-Wert: 20.516071657587926
# pid-all-dn-3.csv
# Maximaler phi_deg-Wert: 33.613256600703906
# pid-all-dn-7.csv
# Maximaler phi_deg-Wert: 33.404413484378715
# pid-all-dn-13.csv
# Maximaler phi_deg-Wert: 20.13820599169915
# pid-all-dn-4.csv
# Maximaler phi_deg-Wert: 21.883607323006174
# pid-all-dn-15.csv
# Maximaler phi_deg-Wert: 20.685552573387625
# pid-all-dn-24.csv
# Maximaler phi_deg-Wert: 380.5213252692093
# pid-all-dn-2.csv
# Maximaler phi_deg-Wert: 20.71763820991495
# pid-all-dn-25.csv
# Maximaler phi_deg-Wert: 20.60883352461961
# pid-all-dn-9.csv
# Maximaler phi_deg-Wert: 380.6021123183227
# pid-all-dn-18.csv
# Maximaler phi_deg-Wert: 20.154306105742325
# pid-all-dn-22.csv
# Maximaler phi_deg-Wert: 384.4042602468109
# pid-all-dn-1.csv
# Maximaler phi_deg-Wert: 20.771438946877737
# pid-all-dn-20.csv
# Maximaler phi_deg-Wert: 20.779403060230052
# pid-all-dn-10.csv
# Maximaler phi_deg-Wert: 20.67134322006838
# pid-all-dn-6.csv
# Maximaler phi_deg-Wert: 20.118095173090058
# pid-all-dn-0.csv
# Maximaler phi_deg-Wert: 20.750124916898866
# pid-all-dn-5.csv
# Maximaler phi_deg-Wert: 20.61949053960904
# pid-all-dn-14.csv
# Maximaler phi_deg-Wert: 20.735342605784492
# pid-all-dn-8.csv
# Maximaler phi_deg-Wert: 20.69941815202979
# pid-all-dn-11.csv
# Maximaler phi_deg-Wert: 20.107438158100624
# pid-all-dn-19.csv
# Maximaler phi_deg-Wert: 20.72491477391311
# pid-all-dn-29.csv
# Maximaler phi_deg-Wert: 20.261220030313737
# pid-all-dn-17.csv
# Maximaler phi_deg-Wert: 20.8431159670486
# pid-all-dn-12.csv
# Maximaler phi_deg-Wert: 20.656560908954003
# pid-all-dn-23.csv
# Maximaler phi_deg-Wert: 20.69454801077118
# pid-all-dn-16.csv
# Maximaler phi_deg-Wert: 20.652664795947118
# pid-all-dn-21.csv
# Maximaler phi_deg-Wert: 20.69294372894481
# pid-all-dn-26.csv
# Maximaler phi_deg-Wert: 20.537729462243874
# count    30.000000
# mean     -1.362360
# std       4.213525
# min     -23.242434
# 1%      -17.627854
# 25%      -0.447977
# 50%      -0.389791
# 75%      -0.351472
# 99%      -0.257826
# max      -0.250493
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.448014, -0.342436]

# %%
phi_medians_5g_1_pid_angle = median(data_sets_5g_1_pid_angle, t)
# Out:
# pid-angle-dn-17.csv
# Maximaler phi_deg-Wert: 20.607458425911293
# pid-angle-dn-20.csv
# Maximaler phi_deg-Wert: 20.559043492222738
# pid-angle-dn-29.csv
# Maximaler phi_deg-Wert: 20.18152160101104
# pid-angle-dn-21.csv
# Maximaler phi_deg-Wert: 20.479459654479065
# pid-angle-dn-5.csv
# Maximaler phi_deg-Wert: 20.41465812784977
# pid-angle-dn-0.csv
# Maximaler phi_deg-Wert: 20.522832559570467
# pid-angle-dn-1.csv
# Maximaler phi_deg-Wert: 20.540078589203908
# pid-angle-dn-19.csv
# Maximaler phi_deg-Wert: 20.502950924079432
# pid-angle-dn-27.csv
# Maximaler phi_deg-Wert: 20.34739288270141
# pid-angle-dn-11.csv
# Maximaler phi_deg-Wert: 20.1073235665416
# pid-angle-dn-14.csv
# Maximaler phi_deg-Wert: 20.509826417621
# pid-angle-dn-9.csv
# Maximaler phi_deg-Wert: 29.063570636908576
# pid-angle-dn-16.csv
# Maximaler phi_deg-Wert: 20.448004271526386
# pid-angle-dn-8.csv
# Maximaler phi_deg-Wert: 20.472698752496523
# pid-angle-dn-15.csv
# Maximaler phi_deg-Wert: 20.465250301159823
# pid-angle-dn-3.csv
# Maximaler phi_deg-Wert: 20.121590215640357
# pid-angle-dn-23.csv
# Maximaler phi_deg-Wert: 20.46868804793061
# pid-angle-dn-26.csv
# Maximaler phi_deg-Wert: 20.348596094071187
# pid-angle-dn-18.csv
# Maximaler phi_deg-Wert: 20.15401962684476
# pid-angle-dn-6.csv
# Maximaler phi_deg-Wert: 20.117923285751516
# pid-angle-dn-28.csv
# Maximaler phi_deg-Wert: 20.502435262063813
# pid-angle-dn-4.csv
# Maximaler phi_deg-Wert: 20.119126497121293
# pid-angle-dn-25.csv
# Maximaler phi_deg-Wert: 20.415460268762953
# pid-angle-dn-7.csv
# Maximaler phi_deg-Wert: 20.131559681275633
# pid-angle-dn-24.csv
# Maximaler phi_deg-Wert: 383.23771817592456
# pid-angle-dn-2.csv
# Maximaler phi_deg-Wert: 20.485131936650863
# pid-angle-dn-22.csv
# Maximaler phi_deg-Wert: 383.03546407424335
# pid-angle-dn-12.csv
# Maximaler phi_deg-Wert: 20.45046799004545
# pid-angle-dn-10.csv
# Maximaler phi_deg-Wert: 20.463474131994918
# pid-angle-dn-13.csv
# Maximaler phi_deg-Wert: 20.137976808581097
# count    30.000000
# mean     -1.651673
# std       5.994570
# min     -26.532873
# 1%      -24.689619
# 25%      -0.392655
# 50%      -0.387674
# 75%      -0.228229
# 99%       2.268943
# max       2.813504
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.392729, -0.182611]

# %%
phi_medians_5g_1_lqr_angle = median(data_sets_5g_1_lqr_angle, t)
# Out:
# lqr-angle-dn-7.csv
# Maximaler phi_deg-Wert: 20.15762926095408
# lqr-angle-dn-6.csv
# Maximaler phi_deg-Wert: 20.14124266801334
# lqr-angle-dn-25.csv
# Maximaler phi_deg-Wert: 20.14846193623199
# lqr-angle-dn-21.csv
# Maximaler phi_deg-Wert: 20.174588811689958
# lqr-angle-dn-15.csv
# Maximaler phi_deg-Wert: 20.168343571723028
# lqr-angle-dn-28.csv
# Maximaler phi_deg-Wert: 20.18249562926276
# lqr-angle-dn-27.csv
# Maximaler phi_deg-Wert: 20.12319449746672
# lqr-angle-dn-17.csv
# Maximaler phi_deg-Wert: 20.22541016811806
# lqr-angle-dn-29.csv
# Maximaler phi_deg-Wert: 20.175906614618757
# lqr-angle-dn-2.csv
# Maximaler phi_deg-Wert: 20.17579202305973
# lqr-angle-dn-26.csv
# Maximaler phi_deg-Wert: 20.12319449746672
# lqr-angle-dn-16.csv
# Maximaler phi_deg-Wert: 20.161811852858538
# lqr-angle-dn-10.csv
# Maximaler phi_deg-Wert: 20.168228980164002
# lqr-angle-dn-23.csv
# Maximaler phi_deg-Wert: 20.169718670431344
# lqr-angle-dn-13.csv
# Maximaler phi_deg-Wert: 20.165077712290785
# lqr-angle-dn-0.csv
# Maximaler phi_deg-Wert: 20.190803517292156
# lqr-angle-dn-20.csv
# Maximaler phi_deg-Wert: 20.206101490422153
# lqr-angle-dn-5.csv
# Maximaler phi_deg-Wert: 20.149607851822253
# lqr-angle-dn-24.csv
# Maximaler phi_deg-Wert: 20.145769034594874
# lqr-angle-dn-4.csv
# Maximaler phi_deg-Wert: 20.142846949839708
# lqr-angle-dn-8.csv
# Maximaler phi_deg-Wert: 20.171552135375762
# lqr-angle-dn-3.csv
# Maximaler phi_deg-Wert: 20.145769034594874
# lqr-angle-dn-22.csv
# Maximaler phi_deg-Wert: 20.086124128121757
# lqr-angle-dn-19.csv
# Maximaler phi_deg-Wert: 20.1839853195301
# lqr-angle-dn-9.csv
# Maximaler phi_deg-Wert: 20.16536419118835
# lqr-angle-dn-18.csv
# Maximaler phi_deg-Wert: 20.184271798427666
# lqr-angle-dn-14.csv
# Maximaler phi_deg-Wert: 20.185704192915495
# lqr-angle-dn-11.csv
# Maximaler phi_deg-Wert: 20.12869489229998
# lqr-angle-dn-1.csv
# Maximaler phi_deg-Wert: 20.198996813762527
# lqr-angle-dn-12.csv
# Maximaler phi_deg-Wert: 20.162155627535615
# count    30.000000
# mean      0.076515
# std       0.001158
# min       0.072897
# 1%        0.073460
# 25%       0.075818
# 50%       0.076807
# 75%       0.077126
# 99%       0.078820
# max       0.079009
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [0.075815, 0.077156]

# %%
data = [phi_medians_5g_1_lqr, phi_medians_5g_1_pid, phi_medians_5g_1_pid_angle, phi_medians_5g_1_lqr_angle]

plt.boxplot(data, positions=[1, 2, 3,4,], widths=0.6)
plt.xticks([1, 2,3 ,4], ['lqr', 'pid', 'pid_angle', 'lqr_angle'])
plt.title("Normaldistribution with μ = 10ms and σ = 2ms")
plt.ylabel("phi-Median")
plt.grid(True)


plt.savefig('ND_10_2_plotbox.png', dpi=300)
plt.show()
