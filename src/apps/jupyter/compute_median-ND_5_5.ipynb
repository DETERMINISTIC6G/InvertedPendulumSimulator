# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_sets_lqr = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/truncnormal_5_5/lqr-all-dn/"

data_sets_pid = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/truncnormal_5_5/pid-all-dn/"

data_sets_pid_angle = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/truncnormal_5_5/pid-angle-dn/"

data_sets_lqr_angle = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/truncnormal_5_5/lqr-angle-dn/"

# %%
def stable_time(df_delay, threshold=0.00872665, window_duration=5.0):
    t = df_delay['t'].values
    angle = np.abs(df_delay['phi'].values)
    is_stable = angle < threshold
    n = len(t)
    start_idx = 0
    end_idx = 0

    while start_idx < n:
        while end_idx < n and t[end_idx] - t[start_idx] < window_duration:
            end_idx += 1
        
        if end_idx == n:
            break

        if is_stable[start_idx:end_idx].all():
            return t[start_idx]

        start_idx += 1

    return float("inf")

# %%
def median(data_sets, t):
    phi_medians = []
    phi_mse = []
    for filename in os.listdir(data_sets):
        if filename.endswith(".csv"):
            filepath = os.path.join(data_sets, filename)
            df = pd.read_csv(filepath, names= ['t', 'position', 'vx', 'phi', 'omega'], header=None, skiprows=1)
            df = df[df["t"] <= t]
            if "phi" in df.columns:
                
                df["phi_deg"] = np.degrees(df["phi"])
                print(filename)
                print("Maximaler phi_deg-Wert:", df["phi_deg"].max())
                print(f"Stabilization time: {stable_time(df):.6f}")
                median_phi = df["phi_deg"].median()
                phi_mse.append((df["phi_deg"]**2).mean())
                phi_medians.append(median_phi)
    phi_medians_sorted = np.sort(phi_medians)

    # 99% Confidence interval
    confidence_level = 0.99
    n = len(phi_medians_sorted )
    
    z = 1.288  # z-value for  99 % CI
    lower_idx = max(0, int(np.floor(0.5 * n - z * np.sqrt(n))))
    upper_idx = min(n - 1, int(np.ceil(0.5 * n + z * np.sqrt(n))))
    
    ci_lower = phi_medians_sorted[lower_idx]
    ci_upper = phi_medians_sorted[upper_idx]
    median = np.median(phi_medians_sorted )
    df = pd.DataFrame(phi_medians_sorted, columns=["medians"])
    summary = df["medians"].describe(percentiles=[0.01, 0.25, 0.5, 0.75, 0.99])
    print(summary)
    print(f"99% Confidence Interval for Median phy: [{ci_lower:.6f}, {ci_upper:.6f}]")
    
    return phi_medians_sorted, phi_mse

# %%
t = 60

# %%
phi_medians_lqr, phi_mse_lqr = median(data_sets_lqr, t)
# Out:
# lqr-all-dn-12.csv
# Maximaler phi_deg-Wert: 20.53486467326822
# Stabilization time: 5.426300
# lqr-all-dn-6.csv
# Maximaler phi_deg-Wert: 20.601213185944367
# Stabilization time: 5.425800
# lqr-all-dn-29.csv
# Maximaler phi_deg-Wert: 20.540594251219527
# Stabilization time: 5.426100
# lqr-all-dn-13.csv
# Maximaler phi_deg-Wert: 20.522546080672907
# Stabilization time: 5.426700
# lqr-all-dn-18.csv
# Maximaler phi_deg-Wert: 20.522431489113877
# Stabilization time: 5.426500
# lqr-all-dn-16.csv
# Maximaler phi_deg-Wert: 20.59439498818231
# Stabilization time: 5.425900
# lqr-all-dn-7.csv
# Maximaler phi_deg-Wert: 20.503180107197483
# Stabilization time: 5.427000
# lqr-all-dn-8.csv
# Maximaler phi_deg-Wert: 20.50329469875651
# Stabilization time: 5.426700
# lqr-all-dn-23.csv
# Maximaler phi_deg-Wert: 20.5045552059058
# Stabilization time: 5.426700
# lqr-all-dn-19.csv
# Maximaler phi_deg-Wert: 20.51337875595081
# Stabilization time: 5.426900
# lqr-all-dn-27.csv
# Maximaler phi_deg-Wert: 20.483355767485957
# Stabilization time: 5.427100
# lqr-all-dn-0.csv
# Maximaler phi_deg-Wert: 20.521228277744104
# Stabilization time: 5.426900
# lqr-all-dn-10.csv
# Maximaler phi_deg-Wert: 20.52936427843496
# Stabilization time: 5.426500
# lqr-all-dn-28.csv
# Maximaler phi_deg-Wert: 20.55039182951626
# Stabilization time: 5.426300
# lqr-all-dn-11.csv
# Maximaler phi_deg-Wert: 20.496476500994454
# Stabilization time: 5.426900
# lqr-all-dn-3.csv
# Maximaler phi_deg-Wert: 20.49343982468026
# Stabilization time: 5.426700
# lqr-all-dn-26.csv
# Maximaler phi_deg-Wert: 20.45258793388743
# Stabilization time: 5.427300
# lqr-all-dn-9.csv
# Maximaler phi_deg-Wert: 20.542083941486865
# Stabilization time: 5.426700
# lqr-all-dn-24.csv
# Maximaler phi_deg-Wert: 20.511717178344934
# Stabilization time: 5.426900
# lqr-all-dn-20.csv
# Maximaler phi_deg-Wert: 20.480548274289816
# Stabilization time: 5.426900
# lqr-all-dn-4.csv
# Maximaler phi_deg-Wert: 20.471552836906262
# Stabilization time: 5.427100
# lqr-all-dn-17.csv
# Maximaler phi_deg-Wert: 20.48226714767521
# Stabilization time: 5.426800
# lqr-all-dn-21.csv
# Maximaler phi_deg-Wert: 20.521915827098262
# Stabilization time: 5.426700
# lqr-all-dn-5.csv
# Maximaler phi_deg-Wert: 20.473099822953117
# Stabilization time: 5.427000
# lqr-all-dn-1.csv
# Maximaler phi_deg-Wert: 20.451155539399604
# Stabilization time: 5.427300
# lqr-all-dn-22.csv
# Maximaler phi_deg-Wert: 20.493898190916365
# Stabilization time: 5.427100
# lqr-all-dn-14.csv
# Maximaler phi_deg-Wert: 20.49515869806565
# Stabilization time: 5.426800
# lqr-all-dn-25.csv
# Maximaler phi_deg-Wert: 20.554746308759256
# Stabilization time: 5.426300
# lqr-all-dn-15.csv
# Maximaler phi_deg-Wert: 20.50220607894576
# Stabilization time: 5.426900
# lqr-all-dn-2.csv
# Maximaler phi_deg-Wert: 20.41133497263801
# Stabilization time: 5.427600
# count    3.000000e+01
# mean    -1.091828e-19
# std      4.295381e-23
# min     -1.092857e-19
# 1%      -1.092750e-19
# 25%     -1.092084e-19
# 50%     -1.091874e-19
# 75%     -1.091430e-19
# 99%     -1.091101e-19
# max     -1.091061e-19
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000000, -0.000000]

# %%
phi_medians_pid, phi_mse_pid = median(data_sets_pid, t)
# Out:
# pid-all-dn-28.csv
# Maximaler phi_deg-Wert: 20.23973411299633
# Stabilization time: 7.505300
# pid-all-dn-27.csv
# Maximaler phi_deg-Wert: 20.19366830626781
# Stabilization time: 7.525900
# pid-all-dn-3.csv
# Maximaler phi_deg-Wert: 20.194585038740023
# Stabilization time: 7.532600
# pid-all-dn-7.csv
# Maximaler phi_deg-Wert: 20.21079974434222
# Stabilization time: 7.524800
# pid-all-dn-13.csv
# Maximaler phi_deg-Wert: 20.22002436484383
# Stabilization time: 7.516500
# pid-all-dn-4.csv
# Maximaler phi_deg-Wert: 20.105776580494744
# Stabilization time: 7.543500
# pid-all-dn-15.csv
# Maximaler phi_deg-Wert: 20.252511071827747
# Stabilization time: 7.514100
# pid-all-dn-24.csv
# Maximaler phi_deg-Wert: 20.224321548307312
# Stabilization time: 7.509500
# pid-all-dn-2.csv
# Maximaler phi_deg-Wert: 20.078446493667002
# Stabilization time: 8.205400
# pid-all-dn-25.csv
# Maximaler phi_deg-Wert: 20.306369104570045
# Stabilization time: 7.491300
# pid-all-dn-9.csv
# Maximaler phi_deg-Wert: 20.301327075972893
# Stabilization time: 7.484900
# pid-all-dn-18.csv
# Maximaler phi_deg-Wert: 20.253026733843367
# Stabilization time: 7.506000
# pid-all-dn-22.csv
# Maximaler phi_deg-Wert: 20.1874803620804
# Stabilization time: 7.536500
# pid-all-dn-1.csv
# Maximaler phi_deg-Wert: 20.13138779393709
# Stabilization time: 7.539700
# pid-all-dn-20.csv
# Maximaler phi_deg-Wert: 20.17837033313782
# Stabilization time: 8.147800
# pid-all-dn-10.csv
# Maximaler phi_deg-Wert: 20.269986284579236
# Stabilization time: 7.502300
# pid-all-dn-6.csv
# Maximaler phi_deg-Wert: 20.424570297705536
# Stabilization time: 7.464400
# pid-all-dn-0.csv
# Maximaler phi_deg-Wert: 20.255146677685353
# Stabilization time: 7.515000
# pid-all-dn-5.csv
# Maximaler phi_deg-Wert: 20.175333656823625
# Stabilization time: 7.538300
# pid-all-dn-14.csv
# Maximaler phi_deg-Wert: 20.039198884700543
# Stabilization time: 9.603800
# pid-all-dn-8.csv
# Maximaler phi_deg-Wert: 20.23744228181581
# Stabilization time: 7.524100
# pid-all-dn-11.csv
# Maximaler phi_deg-Wert: 20.029745081080883
# Stabilization time: 9.762100
# pid-all-dn-19.csv
# Maximaler phi_deg-Wert: 20.193954785165378
# Stabilization time: 7.526800
# pid-all-dn-29.csv
# Maximaler phi_deg-Wert: 20.261563804990814
# Stabilization time: 7.500300
# pid-all-dn-17.csv
# Maximaler phi_deg-Wert: 20.029745081080883
# Stabilization time: 9.746600
# pid-all-dn-12.csv
# Maximaler phi_deg-Wert: 20.26356915727377
# Stabilization time: 7.501800
# pid-all-dn-23.csv
# Maximaler phi_deg-Wert: 20.04068857496788
# Stabilization time: 9.123200
# pid-all-dn-16.csv
# Maximaler phi_deg-Wert: 20.459005061192894
# Stabilization time: 7.448100
# pid-all-dn-21.csv
# Maximaler phi_deg-Wert: 20.238015239610938
# Stabilization time: 7.515600
# pid-all-dn-26.csv
# Maximaler phi_deg-Wert: 20.08801488884569
# Stabilization time: 7.570700
# count    3.000000e+01
# mean    -2.297573e-09
# std      1.876277e-10
# min     -3.109284e-09
# 1%      -2.964892e-09
# 25%     -2.318235e-09
# 50%     -2.248044e-09
# 75%     -2.202067e-09
# 99%     -2.090340e-09
# max     -2.065158e-09
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000000, -0.000000]

# %%
phi_medians_pid_angle, phi_mse_pid_angle = median(data_sets_pid_angle, t)
# Out:
# pid-angle-dn-17.csv
# Maximaler phi_deg-Wert: 20.02968778530137
# Stabilization time: 2.360300
# pid-angle-dn-20.csv
# Maximaler phi_deg-Wert: 20.11717844061785
# Stabilization time: 4.934300
# pid-angle-dn-29.csv
# Maximaler phi_deg-Wert: 20.180490276979803
# Stabilization time: 5.027400
# pid-angle-dn-21.csv
# Maximaler phi_deg-Wert: 20.160092979473145
# Stabilization time: 4.975500
# pid-angle-dn-5.csv
# Maximaler phi_deg-Wert: 20.11219370780021
# Stabilization time: 4.916500
# pid-angle-dn-0.csv
# Maximaler phi_deg-Wert: 20.16628092366056
# Stabilization time: 4.974700
# pid-angle-dn-1.csv
# Maximaler phi_deg-Wert: 20.08343122648464
# Stabilization time: 4.883900
# pid-angle-dn-19.csv
# Maximaler phi_deg-Wert: 20.12468418773406
# Stabilization time: 4.923600
# pid-angle-dn-27.csv
# Maximaler phi_deg-Wert: 20.135283906943982
# Stabilization time: 4.945700
# pid-angle-dn-11.csv
# Maximaler phi_deg-Wert: 20.02968778530137
# Stabilization time: 2.363900
# pid-angle-dn-14.csv
# Maximaler phi_deg-Wert: 20.039141588921026
# Stabilization time: 1.932900
# pid-angle-dn-9.csv
# Maximaler phi_deg-Wert: 20.20180430695867
# Stabilization time: 5.045500
# pid-angle-dn-16.csv
# Maximaler phi_deg-Wert: 20.324703754014234
# Stabilization time: 5.171700
# pid-angle-dn-8.csv
# Maximaler phi_deg-Wert: 20.160092979473145
# Stabilization time: 4.969200
# pid-angle-dn-15.csv
# Maximaler phi_deg-Wert: 20.17206779739138
# Stabilization time: 4.991900
# pid-angle-dn-3.csv
# Maximaler phi_deg-Wert: 20.128121934504847
# Stabilization time: 4.945400
# pid-angle-dn-23.csv
# Maximaler phi_deg-Wert: 20.040573983408855
# Stabilization time: 4.870800
# pid-angle-dn-26.csv
# Maximaler phi_deg-Wert: 20.05329364646076
# Stabilization time: 4.800800
# pid-angle-dn-18.csv
# Maximaler phi_deg-Wert: 20.170291628226476
# Stabilization time: 5.010200
# pid-angle-dn-6.csv
# Maximaler phi_deg-Wert: 20.31559372507165
# Stabilization time: 5.158900
# pid-angle-dn-28.csv
# Maximaler phi_deg-Wert: 20.154764471978428
# Stabilization time: 4.983500
# pid-angle-dn-4.csv
# Maximaler phi_deg-Wert: 20.061716126049184
# Stabilization time: 4.849500
# pid-angle-dn-25.csv
# Maximaler phi_deg-Wert: 20.21870656191503
# Stabilization time: 5.065700
# pid-angle-dn-7.csv
# Maximaler phi_deg-Wert: 20.136830892990833
# Stabilization time: 4.941000
# pid-angle-dn-24.csv
# Maximaler phi_deg-Wert: 20.1467430628466
# Stabilization time: 4.962600
# pid-angle-dn-2.csv
# Maximaler phi_deg-Wert: 20.048595392540687
# Stabilization time: 4.807600
# pid-angle-dn-22.csv
# Maximaler phi_deg-Wert: 20.130184582567317
# Stabilization time: 4.933400
# pid-angle-dn-12.csv
# Maximaler phi_deg-Wert: 20.17355748765872
# Stabilization time: 5.023800
# pid-angle-dn-10.csv
# Maximaler phi_deg-Wert: 20.178885995153436
# Stabilization time: 5.004200
# pid-angle-dn-13.csv
# Maximaler phi_deg-Wert: 20.141414555351883
# Stabilization time: 4.961000
# count    30.000000
# mean     -0.000047
# std       0.000030
# min      -0.000062
# 1%       -0.000061
# 25%      -0.000058
# 50%      -0.000057
# 75%      -0.000056
# 99%       0.000045
# max       0.000051
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000058, -0.000056]

# %%
phi_medians_lqr_angle, phi_mse_lqr_angle = median(data_sets_lqr_angle, t)
# Out:
# lqr-angle-dn-7.csv
# Maximaler phi_deg-Wert: 20.046532744478217
# Stabilization time: 2.566800
# lqr-angle-dn-6.csv
# Maximaler phi_deg-Wert: 20.11460013053976
# Stabilization time: 2.624700
# lqr-angle-dn-25.csv
# Maximaler phi_deg-Wert: 20.07707139495869
# Stabilization time: 2.601000
# lqr-angle-dn-21.csv
# Maximaler phi_deg-Wert: 20.055298998743716
# Stabilization time: 2.571300
# lqr-angle-dn-15.csv
# Maximaler phi_deg-Wert: 20.05982536532525
# Stabilization time: 2.585100
# lqr-angle-dn-28.csv
# Maximaler phi_deg-Wert: 20.05254880132709
# Stabilization time: 2.565300
# lqr-angle-dn-27.csv
# Maximaler phi_deg-Wert: 20.046303561360165
# Stabilization time: 2.564200
# lqr-angle-dn-17.csv
# Maximaler phi_deg-Wert: 20.036162208386347
# Stabilization time: 2.549600
# lqr-angle-dn-29.csv
# Maximaler phi_deg-Wert: 20.06274745008042
# Stabilization time: 2.568200
# lqr-angle-dn-2.csv
# Maximaler phi_deg-Wert: 20.01461899528943
# Stabilization time: 2.528100
# lqr-angle-dn-26.csv
# Maximaler phi_deg-Wert: 20.016165981336282
# Stabilization time: 2.514400
# lqr-angle-dn-16.csv
# Maximaler phi_deg-Wert: 20.118668130885187
# Stabilization time: 2.634100
# lqr-angle-dn-10.csv
# Maximaler phi_deg-Wert: 20.062632858521393
# Stabilization time: 2.584400
# lqr-angle-dn-23.csv
# Maximaler phi_deg-Wert: 20.049111054556306
# Stabilization time: 2.567200
# lqr-angle-dn-13.csv
# Maximaler phi_deg-Wert: 20.0473348853914
# Stabilization time: 2.576200
# lqr-angle-dn-0.csv
# Maximaler phi_deg-Wert: 20.05776271726278
# Stabilization time: 2.574100
# lqr-angle-dn-20.csv
# Maximaler phi_deg-Wert: 20.039198884700543
# Stabilization time: 2.553500
# lqr-angle-dn-5.csv
# Maximaler phi_deg-Wert: 20.037594602874176
# Stabilization time: 2.557900
# lqr-angle-dn-24.csv
# Maximaler phi_deg-Wert: 20.049855899689977
# Stabilization time: 2.570200
# lqr-angle-dn-4.csv
# Maximaler phi_deg-Wert: 20.018973474532427
# Stabilization time: 2.527400
# lqr-angle-dn-8.csv
# Maximaler phi_deg-Wert: 20.055241702964206
# Stabilization time: 2.585300
# lqr-angle-dn-3.csv
# Maximaler phi_deg-Wert: 20.043152293486944
# Stabilization time: 2.560500
# lqr-angle-dn-22.csv
# Maximaler phi_deg-Wert: 20.043954434400128
# Stabilization time: 2.565800
# lqr-angle-dn-19.csv
# Maximaler phi_deg-Wert: 20.04154801166058
# Stabilization time: 2.556900
# lqr-angle-dn-9.csv
# Maximaler phi_deg-Wert: 20.070826154991764
# Stabilization time: 2.594100
# lqr-angle-dn-18.csv
# Maximaler phi_deg-Wert: 20.05885133707353
# Stabilization time: 2.583900
# lqr-angle-dn-14.csv
# Maximaler phi_deg-Wert: 20.0473348853914
# Stabilization time: 2.569700
# lqr-angle-dn-11.csv
# Maximaler phi_deg-Wert: 20.036162208386347
# Stabilization time: 2.557500
# lqr-angle-dn-1.csv
# Maximaler phi_deg-Wert: 20.026937587884742
# Stabilization time: 2.546200
# lqr-angle-dn-12.csv
# Maximaler phi_deg-Wert: 20.05993995688428
# Stabilization time: 2.582300
# count    3.000000e+01
# mean     2.881004e-10
# std      6.083788e-12
# min      2.747774e-10
# 1%       2.758290e-10
# 25%      2.850416e-10
# 50%      2.875685e-10
# 75%      2.912608e-10
# 99%      3.036128e-10
# max      3.043664e-10
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [0.000000, 0.000000]

# %%
data = [phi_medians_lqr, phi_medians_pid, phi_medians_pid_angle, phi_medians_lqr_angle]

plt.boxplot(data, positions=[1, 2, 3,4,], widths=0.6)
plt.xticks([1, 2,3 ,4], ['lqr', 'pid', 'pid_angle', 'lqr_angle'])
plt.title("ND(5ms,5ms) data set")
plt.ylabel("phi-Median")
plt.grid(True)


plt.savefig('ND5_5_plotbox.png', dpi=300)
plt.show()

# %%
mse_dict = {
    'lqr': phi_mse_lqr,
    'pid': phi_mse_pid,
    'pid_angle': phi_mse_pid_angle,
    'lqr_angle': phi_mse_lqr_angle,
}

# Plot Setup
fig, axs = plt.subplots(1, 4, figsize=(16, 4), sharey=True)

for i, (label, data) in enumerate(mse_dict.items()):
    axs[i].hist(data, bins=10, color='skyblue', edgecolor='black')
    axs[i].set_title(label)
    axs[i].set_xlabel('MSE, squared degrees')
    axs[i].grid(True)

axs[0].set_ylabel('Count')
plt.suptitle('Histograms of MSE values for ND(5ms, 5ms) data set (4 methods)', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])

plt.savefig('ND5_5_mse_hist.png', dpi=300)
plt.show()
