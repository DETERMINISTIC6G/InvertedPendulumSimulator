# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_sets_5g_1_lqr = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/5g-1/lqr-all-dn/"

data_sets_5g_1_pid = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/5g-1/pid-all-dn/"

data_sets_5g_1_pid_angle = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/5g-1/pid-angle-dn/"

data_sets_5g_1_lqr_angle = "/home/mostovea/6g-projects/InvertedPendulum/src/build/results/5g-1/lqr-angle-dn/"

# %%
def stable_time(df_delay, threshold=0.00872665, window_duration=5.0):
    t = df_delay['t'].values
    angle = np.abs(df_delay['phi'].values)
    is_stable = angle < threshold
    n = len(t)
    start_idx = 0
    end_idx = 0

    while start_idx < n:
        while end_idx < n and t[end_idx] - t[start_idx] < window_duration:
            end_idx += 1
        
        if end_idx == n:
            break

        if is_stable[start_idx:end_idx].all():
            return t[start_idx]

        start_idx += 1

    return float("inf")

# %%
def median(data_sets, t):
    phi_medians = []
    phi_mse = []
    for filename in os.listdir(data_sets):
        if filename.endswith(".csv"):
            filepath = os.path.join(data_sets, filename)
            df = pd.read_csv(filepath, names= ['t', 'position', 'vx', 'phi', 'omega'], header=None, skiprows=1)
            df = df[df["t"] <= t]
            if "phi" in df.columns:
                
                df["phi_deg"] = np.degrees(df["phi"])
                print(filename)
                print("Maximaler phi_deg-Wert:", df["phi_deg"].max())
                print(f"Stabilization time: {stable_time(df):.6f}")
                median_phi = df["phi_deg"].median()
                phi_mse.append((df["phi_deg"]**2).mean())
                phi_medians.append(median_phi)
    phi_medians_sorted = np.sort(phi_medians)

    # 99% Confidence interval
    confidence_level = 0.99
    n = len(phi_medians_sorted )
    
    z = 1.288  # z-value for  99 % CI
    lower_idx = max(0, int(np.floor(0.5 * n - z * np.sqrt(n))))
    upper_idx = min(n - 1, int(np.ceil(0.5 * n + z * np.sqrt(n))))
    
    ci_lower = phi_medians_sorted[lower_idx]
    ci_upper = phi_medians_sorted[upper_idx]
    median = np.median(phi_medians_sorted )
    df = pd.DataFrame(phi_medians_sorted, columns=["medians"])
    summary = df["medians"].describe(percentiles=[0.01, 0.25, 0.5, 0.75, 0.99])
    print(summary)
    print(f"99% Confidence Interval for Median phy: [{ci_lower:.6f}, {ci_upper:.6f}]")
    
    return phi_medians_sorted, phi_mse

# %%
t = 60

# %%
phi_medians_5g_1_lqr, phi_mse_lqr = median(data_sets_5g_1_lqr, t)
# Out:
# lqr-all-dn-12.csv
# Maximaler phi_deg-Wert: 20.6096929613123
# Stabilization time: 5.427500
# lqr-all-dn-6.csv
# Maximaler phi_deg-Wert: 20.57823757835962
# Stabilization time: 5.427800
# lqr-all-dn-29.csv
# Maximaler phi_deg-Wert: 20.603734200242943
# Stabilization time: 5.427500
# lqr-all-dn-13.csv
# Maximaler phi_deg-Wert: 20.5764041134152
# Stabilization time: 5.427800
# lqr-all-dn-18.csv
# Maximaler phi_deg-Wert: 20.58562873391681
# Stabilization time: 5.427800
# lqr-all-dn-16.csv
# Maximaler phi_deg-Wert: 20.582076395587
# Stabilization time: 5.427800
# lqr-all-dn-7.csv
# Maximaler phi_deg-Wert: 20.58792056509733
# Stabilization time: 5.427800
# lqr-all-dn-8.csv
# Maximaler phi_deg-Wert: 20.599093242102384
# Stabilization time: 5.427600
# lqr-all-dn-23.csv
# Maximaler phi_deg-Wert: 20.60104129860583
# Stabilization time: 5.427700
# lqr-all-dn-19.csv
# Maximaler phi_deg-Wert: 20.58706112840464
# Stabilization time: 5.427700
# lqr-all-dn-27.csv
# Maximaler phi_deg-Wert: 20.59072805829347
# Stabilization time: 5.427800
# lqr-all-dn-0.csv
# Maximaler phi_deg-Wert: 20.584081747869956
# Stabilization time: 5.427800
# lqr-all-dn-10.csv
# Maximaler phi_deg-Wert: 20.595712791111108
# Stabilization time: 5.427700
# lqr-all-dn-28.csv
# Maximaler phi_deg-Wert: 20.594853354418415
# Stabilization time: 5.427600
# lqr-all-dn-11.csv
# Maximaler phi_deg-Wert: 20.584597409885575
# Stabilization time: 5.427800
# lqr-all-dn-3.csv
# Maximaler phi_deg-Wert: 20.607229242793238
# Stabilization time: 5.427500
# lqr-all-dn-26.csv
# Maximaler phi_deg-Wert: 20.61782896200316
# Stabilization time: 5.427400
# lqr-all-dn-9.csv
# Maximaler phi_deg-Wert: 20.58625898749145
# Stabilization time: 5.427700
# lqr-all-dn-24.csv
# Maximaler phi_deg-Wert: 20.577378141666923
# Stabilization time: 5.427900
# lqr-all-dn-20.csv
# Maximaler phi_deg-Wert: 20.59307718525351
# Stabilization time: 5.427700
# lqr-all-dn-4.csv
# Maximaler phi_deg-Wert: 20.589639438482724
# Stabilization time: 5.427700
# lqr-all-dn-17.csv
# Maximaler phi_deg-Wert: 20.59330636837156
# Stabilization time: 5.427700
# lqr-all-dn-21.csv
# Maximaler phi_deg-Wert: 20.59588467844965
# Stabilization time: 5.427700
# lqr-all-dn-5.csv
# Maximaler phi_deg-Wert: 20.58975403004175
# Stabilization time: 5.427700
# lqr-all-dn-1.csv
# Maximaler phi_deg-Wert: 20.59107183297055
# Stabilization time: 5.427700
# lqr-all-dn-22.csv
# Maximaler phi_deg-Wert: 20.59983808723605
# Stabilization time: 5.427600
# lqr-all-dn-14.csv
# Maximaler phi_deg-Wert: 20.604536341156127
# Stabilization time: 5.427600
# lqr-all-dn-25.csv
# Maximaler phi_deg-Wert: 20.583909860531417
# Stabilization time: 5.427700
# lqr-all-dn-15.csv
# Maximaler phi_deg-Wert: 20.59233234011984
# Stabilization time: 5.427700
# lqr-all-dn-2.csv
# Maximaler phi_deg-Wert: 20.580529409540144
# Stabilization time: 5.427800
# count    3.000000e+01
# mean    -1.127139e-19
# std      1.682480e-23
# min     -1.127621e-19
# 1%      -1.127570e-19
# 25%     -1.127246e-19
# 50%     -1.127124e-19
# 75%     -1.127039e-19
# 99%     -1.126836e-19
# max     -1.126819e-19
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000000, -0.000000]

# %%
phi_mse_sorted = np.sort(phi_mse_lqr)
median_mse = np.median(phi_mse_sorted)

print(f"MSE median: {median_mse:.6f}")
# Out:
# MSE median: 3.190685

# %%
phi_medians_5g_1_pid, phi_mse_pid = median(data_sets_5g_1_pid, t)
# Out:
# pid-all-dn-28.csv
# Maximaler phi_deg-Wert: 20.31467699259944
# Stabilization time: 8.170700
# pid-all-dn-27.csv
# Maximaler phi_deg-Wert: 23.13466066867433
# Stabilization time: 7.798000
# pid-all-dn-3.csv
# Maximaler phi_deg-Wert: 20.063434999434577
# Stabilization time: 9.819900
# pid-all-dn-7.csv
# Maximaler phi_deg-Wert: 20.05146018151634
# Stabilization time: 9.811200
# pid-all-dn-13.csv
# Maximaler phi_deg-Wert: 20.047449476950426
# Stabilization time: 10.399700
# pid-all-dn-4.csv
# Maximaler phi_deg-Wert: 20.059882661104766
# Stabilization time: 9.242100
# pid-all-dn-15.csv
# Maximaler phi_deg-Wert: 20.32097952834588
# Stabilization time: 8.161100
# pid-all-dn-24.csv
# Maximaler phi_deg-Wert: 399.77958267914653
# Stabilization time: inf
# pid-all-dn-2.csv
# Maximaler phi_deg-Wert: 20.049855899689977
# Stabilization time: 10.408500
# pid-all-dn-25.csv
# Maximaler phi_deg-Wert: 20.275830454089572
# Stabilization time: 8.189000
# pid-all-dn-9.csv
# Maximaler phi_deg-Wert: 20.05146018151634
# Stabilization time: 10.408300
# pid-all-dn-18.csv
# Maximaler phi_deg-Wert: 20.053923900035404
# Stabilization time: 9.799300
# pid-all-dn-22.csv
# Maximaler phi_deg-Wert: 20.325334007588875
# Stabilization time: 8.164600
# pid-all-dn-1.csv
# Maximaler phi_deg-Wert: 20.0587367455145
# Stabilization time: 9.054200
# pid-all-dn-20.csv
# Maximaler phi_deg-Wert: 20.311697612064762
# Stabilization time: 8.163700
# pid-all-dn-10.csv
# Maximaler phi_deg-Wert: 20.055585477641284
# Stabilization time: 9.819600
# pid-all-dn-6.csv
# Maximaler phi_deg-Wert: 20.047449476950426
# Stabilization time: 10.443700
# pid-all-dn-0.csv
# Maximaler phi_deg-Wert: 20.052262322429527
# Stabilization time: 10.271000
# pid-all-dn-5.csv
# Maximaler phi_deg-Wert: 20.278236876829123
# Stabilization time: 8.187300
# pid-all-dn-14.csv
# Maximaler phi_deg-Wert: 20.31593749974873
# Stabilization time: 8.163400
# pid-all-dn-8.csv
# Maximaler phi_deg-Wert: 20.059882661104766
# Stabilization time: 9.309200
# pid-all-dn-11.csv
# Maximaler phi_deg-Wert: 20.05312175912222
# Stabilization time: 10.414200
# pid-all-dn-19.csv
# Maximaler phi_deg-Wert: 20.052262322429527
# Stabilization time: 9.805300
# pid-all-dn-29.csv
# Maximaler phi_deg-Wert: 20.321609781920525
# Stabilization time: 8.164700
# pid-all-dn-17.csv
# Maximaler phi_deg-Wert: 20.06165883026967
# Stabilization time: 10.153700
# pid-all-dn-12.csv
# Maximaler phi_deg-Wert: 20.080910212186065
# Stabilization time: 9.018000
# pid-all-dn-23.csv
# Maximaler phi_deg-Wert: 20.331693839114827
# Stabilization time: 8.155500
# pid-all-dn-16.csv
# Maximaler phi_deg-Wert: 20.052262322429527
# Stabilization time: 10.448500
# pid-all-dn-21.csv
# Maximaler phi_deg-Wert: 20.291701385014697
# Stabilization time: 8.176400
# pid-all-dn-26.csv
# Maximaler phi_deg-Wert: 20.346418854449688
# Stabilization time: 8.150200
# count    3.000000e+01
# mean     2.470017e-02
# std      1.352886e-01
# min     -6.391831e-08
# 1%      -6.370098e-08
# 25%     -4.661474e-08
# 50%     -3.895509e-08
# 75%     -3.820654e-08
# 99%      5.261145e-01
# max      7.410063e-01
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000000, -0.000000]

# %%
phi_mse_sorted = np.sort(phi_mse_pid)
median_mse = np.median(phi_mse_sorted)

print(f"MSE pid median: {median_mse:.6f}")
# Out:
# MSE pid median: 3.316356

# %%
phi_medians_5g_1_pid_angle, phi_mse_pid_angle = median(data_sets_5g_1_pid_angle, t)
# Out:
# pid-angle-dn-17.csv
# Maximaler phi_deg-Wert: 20.061544238710646
# Stabilization time: 3.002900
# pid-angle-dn-20.csv
# Maximaler phi_deg-Wert: 20.20902357517732
# Stabilization time: 4.953100
# pid-angle-dn-29.csv
# Maximaler phi_deg-Wert: 20.21761794210428
# Stabilization time: 4.962100
# pid-angle-dn-21.csv
# Maximaler phi_deg-Wert: 20.191147291969237
# Stabilization time: 4.932500
# pid-angle-dn-5.csv
# Maximaler phi_deg-Wert: 20.180261093861752
# Stabilization time: 4.917700
# pid-angle-dn-0.csv
# Maximaler phi_deg-Wert: 20.05220502665001
# Stabilization time: 1.469200
# pid-angle-dn-1.csv
# Maximaler phi_deg-Wert: 20.05552818186177
# Stabilization time: 4.544900
# pid-angle-dn-19.csv
# Maximaler phi_deg-Wert: 20.05220502665001
# Stabilization time: 4.095000
# pid-angle-dn-27.csv
# Maximaler phi_deg-Wert: 20.056387618554467
# Stabilization time: 6.380400
# pid-angle-dn-11.csv
# Maximaler phi_deg-Wert: 20.053007167563194
# Stabilization time: 2.043600
# pid-angle-dn-14.csv
# Maximaler phi_deg-Wert: 20.209367349854396
# Stabilization time: 4.949800
# pid-angle-dn-9.csv
# Maximaler phi_deg-Wert: 20.05140288573683
# Stabilization time: 2.044000
# pid-angle-dn-16.csv
# Maximaler phi_deg-Wert: 20.05220502665001
# Stabilization time: 2.163300
# pid-angle-dn-8.csv
# Maximaler phi_deg-Wert: 20.05982536532525
# Stabilization time: 3.688500
# pid-angle-dn-15.csv
# Maximaler phi_deg-Wert: 20.214352082672033
# Stabilization time: 4.960400
# pid-angle-dn-3.csv
# Maximaler phi_deg-Wert: 20.06332040787555
# Stabilization time: 4.467000
# pid-angle-dn-23.csv
# Maximaler phi_deg-Wert: 20.22563935123611
# Stabilization time: 4.970000
# pid-angle-dn-26.csv
# Maximaler phi_deg-Wert: 20.232113774321093
# Stabilization time: 4.981900
# pid-angle-dn-18.csv
# Maximaler phi_deg-Wert: 20.05386660425589
# Stabilization time: 5.232500
# pid-angle-dn-6.csv
# Maximaler phi_deg-Wert: 20.047392181170913
# Stabilization time: 2.167900
# pid-angle-dn-28.csv
# Maximaler phi_deg-Wert: 20.20913816673634
# Stabilization time: 4.952900
# pid-angle-dn-4.csv
# Maximaler phi_deg-Wert: 20.05982536532525
# Stabilization time: 4.123000
# pid-angle-dn-25.csv
# Maximaler phi_deg-Wert: 20.179917319184675
# Stabilization time: 4.915200
# pid-angle-dn-7.csv
# Maximaler phi_deg-Wert: 20.05140288573683
# Stabilization time: 4.132500
# pid-angle-dn-24.csv
# Maximaler phi_deg-Wert: 386.152354479755
# Stabilization time: inf
# pid-angle-dn-2.csv
# Maximaler phi_deg-Wert: 20.049798603910464
# Stabilization time: 2.044800
# pid-angle-dn-22.csv
# Maximaler phi_deg-Wert: 20.22019625218237
# Stabilization time: 4.964400
# pid-angle-dn-12.csv
# Maximaler phi_deg-Wert: 20.067904070236594
# Stabilization time: 4.603100
# pid-angle-dn-10.csv
# Maximaler phi_deg-Wert: 20.05552818186177
# Stabilization time: 4.506400
# pid-angle-dn-13.csv
# Maximaler phi_deg-Wert: 20.047392181170913
# Stabilization time: 2.108000
# count    30.000000
# mean     -0.170890
# std       0.935909
# min      -5.126205
# 1%       -3.639623
# 25%      -0.000059
# 50%      -0.000043
# 75%       0.000015
# 99%       0.000081
# max       0.000089
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [-0.000059, 0.000017]

# %%
phi_mse_sorted = np.sort(phi_mse_pid_angle)
median_mse = np.median(phi_mse_sorted)

print(f"MSE pid_angle median: {median_mse:.6f}")
# Out:
# MSE pid_angle median: 2.110044

# %%
phi_medians_5g_1_lqr_angle, phi_mse_lqr_angle = median(data_sets_5g_1_lqr_angle, t)
# Out:
# lqr-angle-dn-7.csv
# Maximaler phi_deg-Wert: 20.061945309167236
# Stabilization time: 2.558300
# lqr-angle-dn-6.csv
# Maximaler phi_deg-Wert: 20.05718975946765
# Stabilization time: 2.553200
# lqr-angle-dn-25.csv
# Maximaler phi_deg-Wert: 20.061945309167236
# Stabilization time: 2.558700
# lqr-angle-dn-21.csv
# Maximaler phi_deg-Wert: 20.065841422174124
# Stabilization time: 2.563600
# lqr-angle-dn-15.csv
# Maximaler phi_deg-Wert: 20.075066042675733
# Stabilization time: 2.573200
# lqr-angle-dn-28.csv
# Maximaler phi_deg-Wert: 20.07300339461326
# Stabilization time: 2.571800
# lqr-angle-dn-27.csv
# Maximaler phi_deg-Wert: 20.067904070236594
# Stabilization time: 2.566200
# lqr-angle-dn-17.csv
# Maximaler phi_deg-Wert: 20.074034718644498
# Stabilization time: 2.571700
# lqr-angle-dn-29.csv
# Maximaler phi_deg-Wert: 20.07615466248648
# Stabilization time: 2.571700
# lqr-angle-dn-2.csv
# Maximaler phi_deg-Wert: 20.060054548443304
# Stabilization time: 2.556700
# lqr-angle-dn-26.csv
# Maximaler phi_deg-Wert: 20.08154046576071
# Stabilization time: 2.577000
# lqr-angle-dn-16.csv
# Maximaler phi_deg-Wert: 20.062919337418958
# Stabilization time: 2.562700
# lqr-angle-dn-10.csv
# Maximaler phi_deg-Wert: 20.066872746205362
# Stabilization time: 2.565600
# lqr-angle-dn-23.csv
# Maximaler phi_deg-Wert: 20.079363226139215
# Stabilization time: 2.576800
# lqr-angle-dn-13.csv
# Maximaler phi_deg-Wert: 20.05718975946765
# Stabilization time: 2.553600
# lqr-angle-dn-0.csv
# Maximaler phi_deg-Wert: 20.062919337418958
# Stabilization time: 2.559600
# lqr-angle-dn-20.csv
# Maximaler phi_deg-Wert: 20.07294609883375
# Stabilization time: 2.571100
# lqr-angle-dn-5.csv
# Maximaler phi_deg-Wert: 20.061945309167236
# Stabilization time: 2.559700
# lqr-angle-dn-24.csv
# Maximaler phi_deg-Wert: 20.054439562051023
# Stabilization time: 2.551800
# lqr-angle-dn-4.csv
# Maximaler phi_deg-Wert: 20.07191477480251
# Stabilization time: 2.571000
# lqr-angle-dn-8.csv
# Maximaler phi_deg-Wert: 20.07191477480251
# Stabilization time: 2.569600
# lqr-angle-dn-3.csv
# Maximaler phi_deg-Wert: 20.076211958265993
# Stabilization time: 2.572100
# lqr-angle-dn-22.csv
# Maximaler phi_deg-Wert: 20.07724328229723
# Stabilization time: 2.574800
# lqr-angle-dn-19.csv
# Maximaler phi_deg-Wert: 20.062919337418958
# Stabilization time: 2.560400
# lqr-angle-dn-9.csv
# Maximaler phi_deg-Wert: 20.061945309167236
# Stabilization time: 2.557700
# lqr-angle-dn-18.csv
# Maximaler phi_deg-Wert: 20.064924689701915
# Stabilization time: 2.561800
# lqr-angle-dn-14.csv
# Maximaler phi_deg-Wert: 20.07294609883375
# Stabilization time: 2.568000
# lqr-angle-dn-11.csv
# Maximaler phi_deg-Wert: 20.063893365670683
# Stabilization time: 2.560900
# lqr-angle-dn-1.csv
# Maximaler phi_deg-Wert: 20.066872746205362
# Stabilization time: 2.563000
# lqr-angle-dn-12.csv
# Maximaler phi_deg-Wert: 20.081483169981198
# Stabilization time: 2.577600
# count    3.000000e+01
# mean     2.872010e-10
# std      1.842809e-12
# min      2.839209e-10
# 1%       2.840170e-10
# 25%      2.857863e-10
# 50%      2.871229e-10
# 75%      2.887306e-10
# 99%      2.901971e-10
# max      2.901974e-10
# Name: medians, dtype: float64
# 99% Confidence Interval for Median phy: [0.000000, 0.000000]

# %%
phi_mse_sorted = np.sort(phi_mse_lqr_angle)
median_mse = np.median(phi_mse_sorted)

print(f"MSE lqr_angle median: {median_mse:.6f}")
# Out:
# MSE lqr_angle median: 0.705792

# %%
data = [phi_medians_5g_1_lqr, phi_medians_5g_1_pid, phi_medians_5g_1_pid_angle, phi_medians_5g_1_lqr_angle]

plt.boxplot(data, positions=[1, 2, 3,4,], widths=0.6)
plt.xticks([1, 2,3 ,4], ['lqr', 'pid', 'pid_angle', 'lqr_angle'])
plt.title("5G-1 data set")
plt.ylabel("phi-Median")
plt.grid(True)


plt.savefig('5g_1_plotbox.png', dpi=300)
plt.show()

# %%
mse_dict = {
    'lqr': phi_mse_lqr,
    'pid': phi_mse_pid,
    'pid_angle': phi_mse_pid_angle,
    'lqr_angle': phi_mse_lqr_angle,
}

# Plot Setup
fig, axs = plt.subplots(1, 4, figsize=(16, 4), sharey=True)

for i, (label, data) in enumerate(mse_dict.items()):
    axs[i].hist(data, bins=10, color='skyblue', edgecolor='black')
    axs[i].set_title(label)
    axs[i].set_xlabel('MSE, squared degrees')
    axs[i].grid(True)

axs[0].set_ylabel('Count')
plt.suptitle('Histograms of MSE values for 5G-1 data set (4 methods)', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])

plt.savefig('5g_1_mse_hist.png', dpi=300)
plt.show()
